# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('glassdoor_reviews.csv');

# %%
df.shape
# Out:
# (838566, 21)

# %%
df.head()
# Out:
#    Unnamed: 0  column_label       firm date_review  \
# 0           1             1  Sotheby-s  2021-05-25
# 1           2             1  Sotheby-s  2021-05-25
# 2           3             1  Sotheby-s  2021-05-24
# 3           4             1  Sotheby-s  2021-05-22
# 4           5             1  Sotheby-s  2021-05-15
#
#                          job_title                             current  \
# 0                Financial Analyst   Former Employee, more than 1 year
# 1                    Administrator                     Former Employee
# 2   Client Services Representative   Former Employee, more than 1 year
# 3               Anonymous Employee                    Current Employee
# 4                    Administrator  Current Employee, less than 1 year
#
#                    location  overall_rating  work_life_balance  \
# 0              New York, NY               1                1.0
# 1                 Hong Kong               4                4.0
# 2  London, England, England               4                5.0
# 3                 Hong Kong               3                2.0
# 4  London, England, England               4                4.0
#
#    culture_values  ...  career_opp  comp_benefits  senior_mgmt  recommend  \
# 0             1.0  ...         1.0            2.0          1.0          x
# 1             5.0  ...         3.0            4.0          4.0          o
# 2             4.0  ...         5.0            4.0          5.0          v
# 3             2.0  ...         3.0            2.0          3.0          o
# 4             4.0  ...         3.0            3.0          3.0          v
#
#   ceo_approv outlook                                           headline  \
# 0          r       x                                        Don't do it
# 1          o       o                        international auction house
# 2          v       v                Fast-paced, difficult and rewarding
# 3          o       o                                             Review
# 4          r       v  Fun job and nice people but huge workload and ...
#
#                                                 pros  \
# 0  People in leadership roles have been there for...
# 1  great exposure, respectful environment and bea...
# 2                    Good team, support and training
# 3    Exposure to artworks, great team of specialists
# 4  Fantastic art, nice enthusiastic people and a ...
#
#                                                 cons use
# 0  Pressure to do whatever the leaders want\r\nNo... NaN
# 1         OT during peak seasons and often underpaid NaN
# 2       High-stress with relatively low conpensation NaN
# 3                 Work life balance, company culture NaN
# 4                     Very low pay and huge workload NaN
#
# [5 rows x 21 columns]

# %%
df.drop(columns=['Unnamed: 0','column_label','recommend','ceo_approv', 'outlook', 'headline', 'pros', 'cons', 'use'], inplace=True,);
df.head()
# Out:
#         firm date_review                        job_title  \
# 0  Sotheby-s  2021-05-25                Financial Analyst
# 1  Sotheby-s  2021-05-25                    Administrator
# 2  Sotheby-s  2021-05-24   Client Services Representative
# 3  Sotheby-s  2021-05-22               Anonymous Employee
# 4  Sotheby-s  2021-05-15                    Administrator
#
#                               current                  location  \
# 0   Former Employee, more than 1 year              New York, NY
# 1                     Former Employee                 Hong Kong
# 2   Former Employee, more than 1 year  London, England, England
# 3                    Current Employee                 Hong Kong
# 4  Current Employee, less than 1 year  London, England, England
#
#    overall_rating  work_life_balance  culture_values  diversity_inclusion  \
# 0               1                1.0             1.0                  1.0
# 1               4                4.0             5.0                  4.0
# 2               4                5.0             4.0                  4.0
# 3               3                2.0             2.0                  3.0
# 4               4                4.0             4.0                  3.0
#
#    career_opp  comp_benefits  senior_mgmt
# 0         1.0            2.0          1.0
# 1         3.0            4.0          4.0
# 2         5.0            4.0          5.0
# 3         3.0            2.0          3.0
# 4         3.0            3.0          3.0

# %%
df.columns
# Out:
# Index(['firm', 'date_review', 'job_title', 'current', 'location',
#        'overall_rating', 'work_life_balance', 'culture_values',
#        'diversity_inclusion', 'career_opp', 'comp_benefits', 'senior_mgmt'],
#       dtype='object')

# %%
df.rename(columns={'firm' : 'Employer', 'date_review' : 'Date Reviewed', 'job_title' : 'Job Title', 'current' : 'Current Status', 'location' : 'Location', 'overall_rating' : 'Overall Rating', 'work_life_balance' : 'Work Life Balance', 'culture_values' : 'Culture Values', 'diversity_inclusion' : 'Diversity Factor', 'career_opp' : 'Career Opportunities', 'comp_benefits' : 'Comp Benefits', 'senior_mgmt' : 'Senior Management'}, inplace = True)
df.head()
# Out:
#     Employer Date Reviewed                        Job Title  \
# 0  Sotheby-s    2021-05-25                Financial Analyst
# 1  Sotheby-s    2021-05-25                    Administrator
# 2  Sotheby-s    2021-05-24   Client Services Representative
# 3  Sotheby-s    2021-05-22               Anonymous Employee
# 4  Sotheby-s    2021-05-15                    Administrator
#
#                        Current Status                  Location  \
# 0   Former Employee, more than 1 year              New York, NY
# 1                     Former Employee                 Hong Kong
# 2   Former Employee, more than 1 year  London, England, England
# 3                    Current Employee                 Hong Kong
# 4  Current Employee, less than 1 year  London, England, England
#
#    Overall Rating  Work Life Balance  Culture Values  Diversity Factor  \
# 0               1                1.0             1.0               1.0
# 1               4                4.0             5.0               4.0
# 2               4                5.0             4.0               4.0
# 3               3                2.0             2.0               3.0
# 4               4                4.0             4.0               3.0
#
#    Career Opportunities  Comp Benefits  Senior Management
# 0                   1.0            2.0                1.0
# 1                   3.0            4.0                4.0
# 2                   5.0            4.0                5.0
# 3                   3.0            2.0                3.0
# 4                   3.0            3.0                3.0

# %%
df.isna().sum()
# Out:
# Employer                     0
# Date Reviewed                0
# Job Title                    0
# Current Status               0
# Location                297338
# Overall Rating               0
# Work Life Balance       149894
# Culture Values          191373
# Diversity Factor        702500
# Career Opportunities    147501
# Comp Benefits           150082
# Senior Management       155876
# dtype: int64

# %%
df.dropna(inplace=True)
df.shape
# Out:
# (109165, 12)

# %%
df.dtypes
# Out:
# Employer                 object
# Date Reviewed            object
# Job Title                object
# Current Status           object
# Location                 object
# Overall Rating            int64
# Work Life Balance       float64
# Culture Values          float64
# Diversity Factor        float64
# Career Opportunities    float64
# Comp Benefits           float64
# Senior Management       float64
# dtype: object

# %%
df['Date Reviewed'] = pd.to_datetime(df['Date Reviewed'])
df.head()
# Out:
#     Employer Date Reviewed                        Job Title  \
# 0  Sotheby-s    2021-05-25                Financial Analyst
# 1  Sotheby-s    2021-05-25                    Administrator
# 2  Sotheby-s    2021-05-24   Client Services Representative
# 3  Sotheby-s    2021-05-22               Anonymous Employee
# 4  Sotheby-s    2021-05-15                    Administrator
#
#                        Current Status                  Location  \
# 0   Former Employee, more than 1 year              New York, NY
# 1                     Former Employee                 Hong Kong
# 2   Former Employee, more than 1 year  London, England, England
# 3                    Current Employee                 Hong Kong
# 4  Current Employee, less than 1 year  London, England, England
#
#    Overall Rating  Work Life Balance  Culture Values  Diversity Factor  \
# 0               1                1.0             1.0               1.0
# 1               4                4.0             5.0               4.0
# 2               4                5.0             4.0               4.0
# 3               3                2.0             2.0               3.0
# 4               4                4.0             4.0               3.0
#
#    Career Opportunities  Comp Benefits  Senior Management
# 0                   1.0            2.0                1.0
# 1                   3.0            4.0                4.0
# 2                   5.0            4.0                5.0
# 3                   3.0            2.0                3.0
# 4                   3.0            3.0                3.0

# %%
df.drop_duplicates(inplace= True)
df.shape
# Out:
# (105001, 12)

# %%
df.tail()
# Out:
#                                 Employer Date Reviewed  \
# 838048  Department-for-Work-And-Pensions    2020-10-08
# 838049  Department-for-Work-And-Pensions    2020-10-08
# 838050  Department-for-Work-And-Pensions    2020-10-06
# 838051  Department-for-Work-And-Pensions    2020-10-06
# 838056  Department-for-Work-And-Pensions    2020-10-01
#
#                       Job Title                        Current Status  \
# 838048     Office Administrator  Current Employee, more than 10 years
# 838049             Case Manager     Former Employee, more than 1 year
# 838050           Dwp Work Coach     Former Employee, more than 1 year
# 838051        Executive Officer                      Current Employee
# 838056   Administrative Officer     Former Employee, more than 1 year
#
#                                              Location  Overall Rating  \
# 838048  Salford, North West England, England, England               3
# 838049                   Manchester, England, England               4
# 838050                     Hastings, England, England               5
# 838051                     Sandwell, England, England               5
# 838056                   Birkenhead, England, England               3
#
#         Work Life Balance  Culture Values  Diversity Factor  \
# 838048                4.0             3.0               3.0
# 838049                5.0             4.0               5.0
# 838050                5.0             5.0               5.0
# 838051                5.0             5.0               5.0
# 838056                3.0             3.0               4.0
#
#         Career Opportunities  Comp Benefits  Senior Management
# 838048                   3.0            3.0                3.0
# 838049                   2.0            4.0                5.0
# 838050                   5.0            5.0                5.0
# 838051                   5.0            5.0                4.0
# 838056                   3.0            4.0                2.0

# %%
df.head()
# Out:
#     Employer Date Reviewed                        Job Title  \
# 0  Sotheby-s    2021-05-25                Financial Analyst
# 1  Sotheby-s    2021-05-25                    Administrator
# 2  Sotheby-s    2021-05-24   Client Services Representative
# 3  Sotheby-s    2021-05-22               Anonymous Employee
# 4  Sotheby-s    2021-05-15                    Administrator
#
#                        Current Status                  Location  \
# 0   Former Employee, more than 1 year              New York, NY
# 1                     Former Employee                 Hong Kong
# 2   Former Employee, more than 1 year  London, England, England
# 3                    Current Employee                 Hong Kong
# 4  Current Employee, less than 1 year  London, England, England
#
#    Overall Rating  Work Life Balance  Culture Values  Diversity Factor  \
# 0               1                1.0             1.0               1.0
# 1               4                4.0             5.0               4.0
# 2               4                5.0             4.0               4.0
# 3               3                2.0             2.0               3.0
# 4               4                4.0             4.0               3.0
#
#    Career Opportunities  Comp Benefits  Senior Management
# 0                   1.0            2.0                1.0
# 1                   3.0            4.0                4.0
# 2                   5.0            4.0                5.0
# 3                   3.0            2.0                3.0
# 4                   3.0            3.0                3.0

# %%
df.reset_index(inplace=True)

# %%
df.head()
# Out:
#    index   Employer Date Reviewed                        Job Title  \
# 0      0  Sotheby-s    2021-05-25                Financial Analyst
# 1      1  Sotheby-s    2021-05-25                    Administrator
# 2      2  Sotheby-s    2021-05-24   Client Services Representative
# 3      3  Sotheby-s    2021-05-22               Anonymous Employee
# 4      4  Sotheby-s    2021-05-15                    Administrator
#
#                        Current Status                  Location  \
# 0   Former Employee, more than 1 year              New York, NY
# 1                     Former Employee                 Hong Kong
# 2   Former Employee, more than 1 year  London, England, England
# 3                    Current Employee                 Hong Kong
# 4  Current Employee, less than 1 year  London, England, England
#
#    Overall Rating  Work Life Balance  Culture Values  Diversity Factor  \
# 0               1                1.0             1.0               1.0
# 1               4                4.0             5.0               4.0
# 2               4                5.0             4.0               4.0
# 3               3                2.0             2.0               3.0
# 4               4                4.0             4.0               3.0
#
#    Career Opportunities  Comp Benefits  Senior Management
# 0                   1.0            2.0                1.0
# 1                   3.0            4.0                4.0
# 2                   5.0            4.0                5.0
# 3                   3.0            2.0                3.0
# 4                   3.0            3.0                3.0

# %%
df.to_csv('out.csv')
